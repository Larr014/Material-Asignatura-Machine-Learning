# %%
import pandas as pd

# %% [markdown]
# #Explorar df

# %% [markdown]
# ## Leer un dataset

# %% [markdown]
# Pandas trabaja los conjuntos de datos como Dataframe, un conjunto de filas y columnas, donde cada fila es una observacion y cada columna una variable

# %%
df = pd.read_csv('/content/dataset.csv')
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df1 = pd.read_csv('/content/dataset.csv',index_col="id")
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# ##Primeras 5 filas

# %%
df.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 3      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 4     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# ##Ultimas 5 filas

# %%
df.tail()
# Out:
#         id                                          full_text  favorites  \
# 22  183743                         Amazing video by Leonardo!      432.0
# 23  183744                                        Thanks man!      430.0
# 24  183745          There is nothing better than programming!      424.0
# 25  183746                                           BORED AF      488.0
# 26  183747  I do not know if i like programming or other t...      318.0
#
#     retweets  mentions country             user  followers  followees
# 22      95.0      18.0  BRASIL       lucasperes       82.0        351
# 23     143.0      28.0  BRASIL       lucasperes        NaN        351
# 24     110.0      29.0  BRASIL       lucasperes       82.0        351
# 25      28.0      27.0  MEXICO  gabrielcarvajal       21.0       2721
# 26      58.0      20.0  BRASIL  isabelladasilva      928.0       9918

# %% [markdown]
# ##Describir dataset

# %%
df.describe()
# Out:
#                   id   favorites    retweets   mentions   followers  \
# count      27.000000   26.000000   26.000000  26.000000   26.000000
# mean   183734.000000  280.538462   80.000000  15.423077  352.807692
# std         7.937254  153.377242   40.303846   9.596554  375.319493
# min    183721.000000   23.000000   21.000000   1.000000   12.000000
# 25%    183727.500000  139.250000   45.500000   8.250000   21.000000
# 50%    183734.000000  305.500000   79.000000  16.000000  332.000000
# 75%    183740.500000  422.500000  110.750000  23.500000  389.000000
# max    183747.000000  500.000000  146.000000  29.000000  982.000000
#
#          followees
# count    27.000000
# mean   1190.185185
# std    1965.735995
# min     129.000000
# 25%     258.000000
# 50%     351.000000
# 75%    1822.000000
# max    9918.000000

# %% [markdown]
# #Valores Faltantes

# %% [markdown]
# ##Eliminar los valores faltantes

# %%
df_filtrado = df.dropna()
df_filtrado
# Out:
#         id                                          full_text  favorites  \
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# 12  183733                           Programming is the best!      467.0
# 13  183734                             I cannot believe this!       50.0
# 14  183735                             Buy this product NOW!!      418.0
# ...

# %% [markdown]
# ##Reemplazar los valores faltantes por 0

# %%
df_filtrado1 = df.fillna(0)
df_filtrado1.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions  country           user  followers  followees
# 0       0.0      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       0.0   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 3      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 4     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# ##Decision en base a cada variable

# %%
df_filtrado2 = df.fillna({"retweets":0,"mentions":-1})
df_filtrado2
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# #Obtener Valores

# %% [markdown]
# ##Valores por variable

# %% [markdown]
# ####Obtener valores de una variable

# %%
df["full_text"]
# Out:
# 0     Flying home to run down from the power to comi...
# 1                   Today we commemorate and MNML Case.
# 2          Today we have reached US$6.55 Billion TT$44…
# 3     Faking It by Joel Atwell. Written by Other cou...
# 4                                       Welcome back! 🙌
# 5     Contest: Win a fan of his ass. #thatisall Thanks!
# 6                                    80's & friends! ✈️
# 7     Thank you guess how did I feel somewhat offend...
# 8           OnePlus 8 international giveaway classifies
# 9                   Here it is.. Retweet this desperate
# 10    Great to advertise during the year I tweeted a...
# 11    Its been in love with the game with the origin...
# 12                             Programming is the best!
# 13                               I cannot believe this!
# 14                               Buy this product NOW!!
# 15    I have one is best color gradients: Just relea...
# 16                                                PIC!!
# ...

# %% [markdown]
# ###Obtener muchas variables

# %%
df[["full_text","mentions"]]
# Out:
#                                             full_text  mentions
# 0   Flying home to run down from the power to comi...      10.0
# 1                 Today we commemorate and MNML Case.       NaN
# 2        Today we have reached US$6.55 Billion TT$44…       6.0
# 3   Faking It by Joel Atwell. Written by Other cou...       3.0
# 4                                     Welcome back! 🙌       9.0
# 5   Contest: Win a fan of his ass. #thatisall Thanks!       6.0
# 6                                  80's & friends! ✈️      22.0
# 7   Thank you guess how did I feel somewhat offend...      10.0
# 8         OnePlus 8 international giveaway classifies      26.0
# 9                 Here it is.. Retweet this desperate      29.0
# 10  Great to advertise during the year I tweeted a...       8.0
# 11  Its been in love with the game with the origin...      19.0
# 12                           Programming is the best!      10.0
# 13                             I cannot believe this!      22.0
# ...

# %% [markdown]
# ##Valores por fila

# %% [markdown]
# ###Obtener una fila por indice

# %%
df.iloc[0]
# Out:
# id                                                      183721
# full_text    Flying home to run down from the power to comi...
# favorites                                                 23.0
# retweets                                                   NaN
# mentions                                                  10.0
# country                                                ECUADOR
# user                                             leonardokuffo
# followers                                                389.0
# followees                                                  258
# Name: 0, dtype: object

# %% [markdown]
# ###Obtener muchas filas por indice

# %%
df.iloc[0:5]
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions  country           user  followers  followees
# 0       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 1      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 2     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 3      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 4     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# ###Obtener una fila por identificador

# %%
df1.loc[183722]
# Out:
# full_text    Today we commemorate and MNML Case.
# favorites                                  500.0
# retweets                                    21.0
# mentions                                     NaN
# country                                   BRASIL
# user                               mateusmartins
# followers                                  982.0
# followees                                   1822
# Name: 183722, dtype: object

# %% [markdown]
# ###Obtener muchas filas por identificador

# %%
df1.loc[[183727,183736]]
# Out:
#                                                 full_text  favorites  \
# id
# 183727                                 80's & friends! ✈️      158.0
# 183736  I have one is best color gradients: Just relea...      361.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183727      40.0      22.0  ECUADOR  leonardokuffo      389.0        258
# 183736      92.0       1.0   MEXICO    pedrojuarez       12.0        129

# %% [markdown]
# ##Valores por variable e identificador

# %% [markdown]
# ###Una variable y un identificador

# %%
df1.loc[183727,"full_text"]
# Out:
# "80's & friends! ✈️"

# %% [markdown]
# ###Muchar variables y muchos identificadores

# %%
df1.loc[[183727,183736],["full_text","mentions"]]
# Out:
#                                                 full_text  mentions
# id
# 183727                                 80's & friends! ✈️      22.0
# 183736  I have one is best color gradients: Just relea...       1.0

# %% [markdown]
# ##Valores por condicion

# %% [markdown]
# ####Una condicion

# %%
df[df["favorites"]>400]
# Out:
#         id                                          full_text  favorites  \
# 1   183722                Today we commemorate and MNML Case.      500.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 12  183733                           Programming is the best!      467.0
# 14  183735                             Buy this product NOW!!      418.0
# 22  183743                         Amazing video by Leonardo!      432.0
# 23  183744                                        Thanks man!      430.0
# 24  183745          There is nothing better than programming!      424.0
# 25  183746                                           BORED AF      488.0
#
#     retweets  mentions  country             user  followers  followees
# 1       21.0       NaN   BRASIL    mateusmartins      982.0       1822
# 5       70.0       6.0   BRASIL    mateusmartins      982.0       1822
# 12      69.0      10.0  ECUADOR    leonardokuffo      389.0        258
# ...

# %% [markdown]
# Ejemplo con textos

# %%
df[df["full_text"].str.contains("Programming")]
# Out:
#         id                    full_text  favorites  retweets  mentions  \
# 12  183733     Programming is the best!      467.0      69.0      10.0
# 19  183740  Programming is a hot topic!      133.0     145.0      15.0
# 20  183741      Programming? i love it!       92.0     146.0       1.0
#
#     country           user  followers  followees
# 12  ECUADOR  leonardokuffo      389.0        258
# 19   BRASIL     lucasperes       82.0        351
# 20  ECUADOR   galocastillo      332.0        378

# %% [markdown]
# Otro ejemplo

# %%
df[df["full_text"]=="Programming is the best!"]
# Out:
#         id                 full_text  favorites  retweets  mentions  country  \
# 12  183733  Programming is the best!      467.0      69.0      10.0  ECUADOR
#
#              user  followers  followees
# 12  leonardokuffo      389.0        258

# %% [markdown]
# ####Muchas condiciones

# %% [markdown]
# * & para and
# * | para or

# %%
df[(df['favorites'] > 400) & (df['retweets'] > 100)]
# Out:
#         id                                  full_text  favorites  retweets  \
# 23  183744                                Thanks man!      430.0     143.0
# 24  183745  There is nothing better than programming!      424.0     110.0
#
#     mentions country        user  followers  followees
# 23      28.0  BRASIL  lucasperes        NaN        351
# 24      29.0  BRASIL  lucasperes       82.0        351

# %% [markdown]
# #Transformar Datos

# %% [markdown]
# ##Crear nueva variable

# %% [markdown]
# ###Basandonos en una variable

# %% [markdown]
# Podemos asociar una funcion

# %%
import random
def calcularGanancias(retweets):
  ganancias = retweets * random.randint(1,10)
  return ganancias

df["ganancias"] = df["retweets"].apply(calcularGanancias)
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# ###Basandonos en una fila

# %% [markdown]
# axis=1 indica que será aplicado a cada fila

# %%
def popularidad(fila):
  resultado = fila["retweets"] / fila["followers"]
  return resultado

df["popularidad"] = df.apply(popularidad,axis=1)
df
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# #Agrupar

# %% [markdown]
# Consiste en unir filas que tengan un mismo valor dentro de una columna. Realizando una transformacion al resto de los datos

# %% [markdown]
# ##Variable

# %%
df_filtrado3 = df.drop(["full_text","user"],axis=1)
df_filtrado3
# Out:
#         id  favorites  retweets  mentions  country  followers  followees  \
# 0   183721       23.0       NaN      10.0  ECUADOR      389.0        258
# 1   183722      500.0      21.0       NaN   BRASIL      982.0       1822
# 2   183723      190.0     123.0       6.0   MEXICO       12.0        129
# 3   183724      131.0      76.0       3.0  ECUADOR      332.0        378
# 4   183725      113.0     130.0       9.0   MEXICO       12.0        129
# 5   183726      492.0      70.0       6.0   BRASIL      982.0       1822
# 6   183727      158.0      40.0      22.0  ECUADOR      389.0        258
# 7   183728        NaN      50.0      10.0   MEXICO       12.0        129
# 8   183729      198.0      82.0      26.0   MEXICO       12.0        129
# 9   183730      272.0      92.0      29.0   BRASIL      982.0       1822
# 10  183731       43.0     111.0       8.0   BRASIL      982.0       1822
# 11  183732      349.0      44.0      19.0   BRASIL      982.0       1822
# ...

# %% [markdown]
# Asegurate de dejar solo las variables numericas

# %%
df_filtrado3.groupby("country").mean()
# Out:
#                     id   favorites   retweets  mentions  followers  \
# country
# BRASIL   183736.090909  339.909091  91.272727    19.600    616.600
# ECUADOR  183732.625000  186.375000  64.857143    11.875    360.500
# MEXICO   183732.500000  294.857143  77.750000    13.750     15.375
#
#            followees   ganancias  popularidad
# country
# BRASIL   1889.363636  613.454545     0.607743
# ECUADOR   318.000000  453.285714     0.186967
# MEXICO   1101.000000  461.750000     5.831845

# %% [markdown]
# ##Variables Especificas

# %%
agrupacion2 = df_filtrado3.groupby("country").agg({
    "followers":"sum",
    "retweets":"mean",
    "mentions":"max"
})
agrupacion2
# Out:
#          followers   retweets  mentions
# country
# BRASIL      6166.0  91.272727      29.0
# ECUADOR     2884.0  64.857143      22.0
# MEXICO       123.0  77.750000      29.0

# %% [markdown]
# ##Multiple

# %%
agrupado_multiple = df.groupby(["country","user"]).agg({
    "id":"count",
    "full_text":"count",
    "followers":"sum",
    "retweets":"mean",
    "mentions":"max"
}).sort_values("followers",ascending=False)
agrupado_multiple
# Out:
#                          id  full_text  followers    retweets  mentions
# country user
# BRASIL  mateusmartins     5          5     4910.0   67.600000      29.0
# ECUADOR leonardokuffo     4          4     1556.0   44.333333      22.0
#         galocastillo      4          4     1328.0   80.250000      17.0
# BRASIL  isabelladasilva   1          1      928.0   58.000000      20.0
#         lucasperes        5          5      328.0  121.600000      29.0
# MEXICO  gabrielcarvajal   3          3       63.0   48.333333      29.0
#         pedrojuarez       5          5       60.0   95.400000      26.0

# %% [markdown]
# Al realizar agrupacion es necesario considerar que generan nuevos indices y columnas. En el ejemplo country y user no serian columnas, si intentas df["user"] no funcionara. Para ello podemos realizar un reinicio de indexacion.

# %% [markdown]
# ###Reinicio de indexacion

# %%
desagrupado = agrupado_multiple.reset_index(1)
desagrupado
# Out:
#                     user  id  full_text  followers    retweets  mentions
# country
# BRASIL     mateusmartins   5          5     4910.0   67.600000      29.0
# ECUADOR    leonardokuffo   4          4     1556.0   44.333333      22.0
# ECUADOR     galocastillo   4          4     1328.0   80.250000      17.0
# BRASIL   isabelladasilva   1          1      928.0   58.000000      20.0
# BRASIL        lucasperes   5          5      328.0  121.600000      29.0
# MEXICO   gabrielcarvajal   3          3       63.0   48.333333      29.0
# MEXICO       pedrojuarez   5          5       60.0   95.400000      26.0

# %% [markdown]
# #Pivotar

# %% [markdown]
# Convertir cada valor unico de una columna en nuevas columnas

# %%
pivote = desagrupado.pivot(columns="user")
pivote
# Out:
#                      id                                                        \
# user    gabrielcarvajal galocastillo isabelladasilva leonardokuffo lucasperes
# country
# BRASIL              NaN          NaN             1.0           NaN        5.0
# ECUADOR             NaN          4.0             NaN           4.0        NaN
# MEXICO              3.0          NaN             NaN           NaN        NaN
#
#                                         full_text               \
# user    mateusmartins pedrojuarez gabrielcarvajal galocastillo
# country
# BRASIL            5.0         NaN             NaN          NaN
# ECUADOR           NaN         NaN             NaN          4.0
# MEXICO            NaN         5.0             3.0          NaN
#
#                          ...   retweets                            \
# user    isabelladasilva  ... lucasperes mateusmartins pedrojuarez
# country                  ...
# BRASIL              1.0  ...      121.6          67.6         NaN
# ...

# %%
pivote_id = pivote["id"]
pivote_id
# Out:
# user     gabrielcarvajal  galocastillo  isabelladasilva  leonardokuffo  \
# country
# BRASIL               NaN           NaN              1.0            NaN
# ECUADOR              NaN           4.0              NaN            4.0
# MEXICO               3.0           NaN              NaN            NaN
#
# user     lucasperes  mateusmartins  pedrojuarez
# country
# BRASIL          5.0            5.0          NaN
# ECUADOR         NaN            NaN          NaN
# MEXICO          NaN            NaN          5.0

# %%
pivote_id = pivote_id.fillna(0)
pivote_id
# Out:
# user     gabrielcarvajal  galocastillo  isabelladasilva  leonardokuffo  \
# country
# BRASIL               0.0           0.0              1.0            0.0
# ECUADOR              0.0           4.0              0.0            4.0
# MEXICO               3.0           0.0              0.0            0.0
#
# user     lucasperes  mateusmartins  pedrojuarez
# country
# BRASIL          5.0            5.0          0.0
# ECUADOR         0.0            0.0          0.0
# MEXICO          0.0            0.0          5.0

# %% [markdown]
# #Transponer

# %%
agrupacion2.transpose()
# Out:
# country         BRASIL      ECUADOR  MEXICO
# followers  6166.000000  2884.000000  123.00
# retweets     91.272727    64.857143   77.75
# mentions     29.000000    22.000000   29.00

# %%
pivote.transpose()
# Out:
# country                    BRASIL      ECUADOR     MEXICO
#           user
# id        gabrielcarvajal     NaN          NaN   3.000000
#           galocastillo        NaN     4.000000        NaN
#           isabelladasilva     1.0          NaN        NaN
#           leonardokuffo       NaN     4.000000        NaN
#           lucasperes          5.0          NaN        NaN
#           mateusmartins       5.0          NaN        NaN
#           pedrojuarez         NaN          NaN   5.000000
# full_text gabrielcarvajal     NaN          NaN   3.000000
#           galocastillo        NaN     4.000000        NaN
#           isabelladasilva     1.0          NaN        NaN
#           leonardokuffo       NaN     4.000000        NaN
#           lucasperes          5.0          NaN        NaN
#           mateusmartins       5.0          NaN        NaN
#           pedrojuarez         NaN          NaN   5.000000
# followers gabrielcarvajal     NaN          NaN  63.000000
# ...
